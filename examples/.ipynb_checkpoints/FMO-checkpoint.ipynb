# %%
# -*- coding: utf-8 -*-
"""
Project: S-QuAPI for CPU
Date Created : 8/15/20
Date Last mod: 8/29/20
Author: Yoshihiro Sato
Description: Exciton dynamics of the FMO complex using S-QuAPI. 
             The default parameters are set to reproduce Fig.3 
             of Phys.Rev.E84(2011)041926.
Notes:
    - select computational mode with mode = 'ser', 'omp', or 'mpi' 
    - To see a quick result, reduce Dkmax value from 4 to 2.
"""

#==============================================================================
#                           Definitions
#==============================================================================
import numpy as np
import subprocess
import sys
import matplotlib.pyplot as plt

bin_dir = '../bin/'
sys.path.append(bin_dir)
import squapi as sq 

#--- Constant (defined in squapi.py):
hbar    = sq.hbar    # The Planck cons in units of [cm^-1 * ps]
kB      = sq.kB      # Boltzmann const in units of [cm^-1 / K]
fs      = sq.fs      # 1 fs in units of [ps]

def shell(cmd):
    '''
    Executes 'cmd' on shell and monitors the shell output real-time.
    '''
    process = subprocess.Popen(cmd, stdout=subprocess.PIPE, shell=True)
    while True:
        output = process.stdout.readline().decode()
        if output == '' and process.poll() is not None:
            break
        if output:
            print(output.strip())
            
def graphics(Dt, Nmax, H):
    # extract rhos from rhos.dat:
    rhos = sq.load_rhos('rhos.dat')
    # Make a graph:
    times = np.array([k * Dt / fs for k in range(Nmax + 1)])
    opts = 'o--k', 's--r', '--g', '-.b', '-y', '-c', '-.m'
    mecs = ['k', 'r', 'g', 'b', 'y', 'c', 'm'] * 3
    sites = 'BChl 1', 'BChl 2', 'BChl 3', 'BChl 4', 'BChl 5', 'BChl 6', 'BChl 7' 
    
    plt.figure(figsize=(4.8, 3.0))
    plt.xlabel('time [fs]')
    plt.ylabel('Site Population')
    plt.ylim(0,1)
    plt.xlim(0,850)
    plt.xticks([0, 125, 250, 375, 500, 625, 750], ['0', ' ', '250', ' ', '500', ' ', '750'])
    plt.yticks([0, 0.25, 0.5, 0.75, 1], ['0', ' ', '0.5', ' ', '1'])
    #plt.grid(b = True, which = 'both', color = '0.65',linestyle = '--')
    for i in range(len(H)):
        plt.plot(times, rhos[:, i, i].real, opts[i], mec=mecs[i], label = sites[i], mfc='none')
    legend = plt.legend(loc='upper right', shadow=False, fontsize='x-small')
    plt.show()
    
#==============================================================================
#                               Model
#==============================================================================
#--- system ---
H0 = [[  240, -87.7,   5.5,  -5.9,   6.7, -13.7,  -9.9],
      [-87.7,   315,  30.8,   8.2,   0.7,  11.8,   4.3],
      [  5.5,  30.8,     0, -53.5,  -2.2,  -9.6,   6.0],
      [ -5.9,   8.2, -53.5,   130, -70.7, -17.0, -63.3],
      [  6.7,   0.7,  -2.2, -70.7,   285,  81.1,  -1.3],
      [-13.7,  11.8,  -9.6, -17.0,  81.1,   435,  39.7],
      [ -9.9,   4.3,   6.0, -63.3,  -1.3,  39.7,   245],
     ]

#--- bath ---
T   = 77                      # Bath temperature in [K]
s   = np.identity(len(H0))    # System-bath coupling matrix
lam = [35] * len(H0)          # Reorganization energies in [cm^-1]
mu  = lam                     # Counter terms in [cm^-1]
wc  = (50 * fs)**(-1)         # Bath cut-off frequency in [1/ps]

# Bath function with the Lorentz-Drude spectral density:
g   = lambda bath, t: sq.gLD(t, lam[bath], wc, T)

#--- initial density matirx
rhosA = np.zeros_like(H0)
rhosA[0,0] = 1                # BChl 1 excited
rhosB = np.zeros_like(H0)
rhosB[5,5] = 1                # BChl 6 excited

#==============================================================================
#                              Parameters 
#==============================================================================
#--- squapi paramters
Dkmax = 2               # The maximum number of memory steps
Nmax  = 40              # The maximu times step
Dt    = 850 * fs / 40   # Time slice of path integral
theta = 4e-6

#============ Selection ==========
# select mode from 'ser' (serial) 'omp' (OpenMP) and 'mpi' (MPI):
mode     = 'omp'
# select the initial density matrix:
rhos0    = rhosA.copy()
system   = True 
init     = True 
squapi   = True  
cont     = False 
#=================================

# ----- Generate system.dat --------------------
if system == True:
    sq.save_system(H0, s, lam, mu, T, Dt, Dkmax, g, scaled=True)

# -----Generate init.dat --------------------
if init == True:
    sq.save_init(rhos0)

#------- Processing with external program
if squapi == True:
    # to make the list of avalable binaries, get output from shell:
    output = subprocess.check_output('ls ' + bin_dir, shell=True)
    # then decode it to UTF-8 and make a list out of it:
    prog_list = output.decode('UTF-8').splitlines()
    # set up binary program based on selection:
    prog = 'squapi'
    if cont == True: prog += '_cont' 
    if mode != 'ser': prog += '_' + mode
    if prog in prog_list:
        # start computing:
        cmd = bin_dir + prog + ' system.dat init.dat ' + str(Nmax) + ' ' + str(theta)
        if mode == 'mpi':
            cmd = 'mpiexec ' + cmd 
    else:
        print('**CANNOT RUN: ' + prog + ' DOES NOT EXIST IN ' + bin_dir + ' **')
        exit(0)

# %%
# Let's run the shell command (cmd) generated above then make a graph:
shell(cmd)
graphics(Dt, Nmax, H0)
# Out:
# ----- Date and Time --------------------
# Sun Aug 30 18:47:19 EDT 2020
# ----- parameters -----------------------
# Dt     = 0.02125 ps
# Nmax   = 40
# Dkmax  = 2
# M      = 7
# theta  = 4e-06
# ----- generate Cn and Wn ---------------
# size of C1 = 49
# size of C2 = 2401  lap time = 0.005393 sec
# ----- generate Cnmap -------------------
# lap time = 0.000561 sec
# ----- generate rhos --------------------
# N = 0 of 40 lap time = 0.001644 sec tr = 1
# N = 1 of 40 lap time = 0.002982 sec tr = 1
# N = 2 of 40 lap time = 0.023339 sec tr = 1
# N = 3 of 40 lap time = 0.069012 sec tr = 1
# N = 4 of 40 lap time = 0.088678 sec tr = 1
# N = 5 of 40 lap time = 0.079669 sec tr = 1
# N = 6 of 40 lap time = 0.074798 sec tr = 1
# N = 7 of 40 lap time = 0.096109 sec tr = 1
# N = 8 of 40 lap time = 0.082342 sec tr = 1
# N = 9 of 40 lap time = 0.099381 sec tr = 1
# N = 10 of 40 lap time = 0.117063 sec tr = 1
# N = 11 of 40 lap time = 0.119908 sec tr = 1
# N = 12 of 40 lap time = 0.127009 sec tr = 1
# N = 13 of 40 lap time = 0.115511 sec tr = 1
# N = 14 of 40 lap time = 0.07666 sec tr = 1
# N = 15 of 40 lap time = 0.095685 sec tr = 1
# N = 16 of 40 lap time = 0.074011 sec tr = 1
# N = 17 of 40 lap time = 0.096826 sec tr = 1
# N = 18 of 40 lap time = 0.128578 sec tr = 1
# N = 19 of 40 lap time = 0.123782 sec tr = 1
# N = 20 of 40 lap time = 0.133465 sec tr = 1
# N = 21 of 40 lap time = 0.08463 sec tr = 1
# N = 22 of 40 lap time = 0.079866 sec tr = 1
# N = 23 of 40 lap time = 0.108538 sec tr = 1
# N = 24 of 40 lap time = 0.070833 sec tr = 1
# N = 25 of 40 lap time = 0.071605 sec tr = 1
# N = 26 of 40 lap time = 0.088639 sec tr = 1
# N = 27 of 40 lap time = 0.103306 sec tr = 1
# N = 28 of 40 lap time = 0.074501 sec tr = 1
# N = 29 of 40 lap time = 0.101346 sec tr = 1
# N = 30 of 40 lap time = 0.073625 sec tr = 1
# N = 31 of 40 lap time = 0.081393 sec tr = 1
# N = 32 of 40 lap time = 0.120994 sec tr = 1
# N = 33 of 40 lap time = 0.110185 sec tr = 1
# N = 34 of 40 lap time = 0.154703 sec tr = 1
# N = 35 of 40 lap time = 0.135232 sec tr = 1
# N = 36 of 40 lap time = 0.110756 sec tr = 1
# N = 37 of 40 lap time = 0.084374 sec tr = 1
# N = 38 of 40 lap time = 0.070642 sec tr = 1
# N = 39 of 40 lap time = 0.099853 sec tr = 1
# N = 40 of 40 lap time = 0.069162 sec tr = 1
# ----- saving D to D.dat ----------------
# lap time = 0.022105 sec
# ----- end -----------------------------
# elapsed_time = 3.8155 sec
# ---------------------------------------
